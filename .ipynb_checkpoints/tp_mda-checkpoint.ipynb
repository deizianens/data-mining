# %%
# for some basic operations
import numpy as np 
import pandas as pd 

# for visualizations
# import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %%
# reading the dataset

data = pd.read_csv('./data/fogo-cruzado.csv', encoding='latin-1')

# check the shape of the data
data.shape
# Out:
# (23689, 23)

# %%
# describing the data
data.describe()
# Out:
#        id_ocorrencia  latitude_ocorrencia  longitude_ocorrencia  \
# count   23689.000000         23689.000000          23689.000000
# mean    15422.612563           -22.852650            -43.292122
# std      9355.107969             0.073667              0.160766
# min        16.000000           -23.063410            -43.875116
# 25%      6708.000000           -22.905251            -43.373074
# 50%     15539.000000           -22.861285            -43.297520
# 75%     23702.000000           -22.811232            -43.215534
# max     31382.000000           -22.474852            -42.614947
#
#        presen_agen_segur_ocorrencia  qtd_morto_civil_ocorrencia  \
# count                  23689.000000                23689.000000
# mean                       0.227532                    0.173329
# std                        0.419248                    0.523684
# min                        0.000000                    0.000000
# 25%                        0.000000                    0.000000
# 50%                        0.000000                    0.000000
# 75%                        0.000000                    0.000000
# max                        1.000000                   12.000000
#
#        qtd_morto_agen_segur_ocorrencia  qtd_ferido_civil_ocorrencia  \
# count                     23689.000000                 23689.000000
# mean                          0.015661                     0.149310
# std                           0.125852                     0.523304
# min                           0.000000                     0.000000
# 25%                           0.000000                     0.000000
# 50%                           0.000000                     0.000000
# 75%                           0.000000                     0.000000
# max                           2.000000                    15.000000
#
#        qtd_ferido_agen_segur_ocorrencia  fonte_ocorrencia  estado_id  \
# count                      23689.000000      23689.000000    23689.0
# mean                           0.030267          0.367259       19.0
# std                            0.190240          0.571280        0.0
# min                            0.000000          0.000000       19.0
# 25%                            0.000000          0.000000       19.0
# 50%                            0.000000          0.000000       19.0
# 75%                            0.000000          1.000000       19.0
# max                            3.000000          2.000000       19.0
#
#           cidade_id  cod_ibge_cidade  populacao_cidade    area_cidade  \
# count  23689.000000     2.368900e+04      2.368900e+04   23689.000000
# mean    3652.639706     3.304001e+06      4.155671e+06   83215.822956
# std       17.725359     1.210367e+03      2.773013e+06   47772.469308
# min     3602.000000     3.300456e+06      3.073200e+04    1939.000000
# 25%     3643.000000     3.303500e+06      8.550480e+05   24771.000000
# 50%     3661.000000     3.304557e+06      6.320446e+06  119746.000000
# 75%     3661.000000     3.304557e+06      6.320446e+06  119746.000000
# max     3678.000000     3.305752e+06      6.320446e+06  119746.000000
#
#        densidade_demo_cidade  cod_ibge_estado
# count           23689.000000          23689.0
# mean               18.797177             33.0
# std                78.473042              0.0
# min                 1.170000             33.0
# 25%                 4.310000             33.0
# 50%                 5.270000             33.0
# 75%                 5.270000             33.0
# max               585.100000             33.0

# %%
# checking the head of the data

data.head()
# Out:
#    id_ocorrencia                                   local_ocorrencia  \
# 0           8758                  Maré; Rio de Janeiro - RJ; Brasil
# 1          10431  R. Alice - Laranjeiras; Rio de Janeiro - RJ; B...
# 2          10430            Areia Branca; Belford Roxo - RJ; Brasil
# 3             16            Santa Cruz; Rio de Janeiro - RJ; Brasil
# 4             17  Rua Barão - Praça Seca; Rio de Janeiro - RJ; B...
#
#    latitude_ocorrencia  longitude_ocorrencia data_ocorrencia hora_ocorrencia  \
# 0           -22.857496            -43.243015      09/01/2018        15:57:00
# 1           -22.935377            -43.194631      19/01/2018        20:54:00
# 2           -22.748600            -43.410628      19/01/2018        18:37:00
# 3           -22.919651            -43.684387      05/07/2016         6:02:00
# 4           -22.898642            -43.352360      05/07/2016        13:44:00
#
#    presen_agen_segur_ocorrencia  qtd_morto_civil_ocorrencia  \
# 0                             0                           0
# 1                             0                           0
# 2                             0                           0
# 3                             1                           0
# 4                             1                           0
#
#    qtd_morto_agen_segur_ocorrencia  qtd_ferido_civil_ocorrencia  ...  \
# 0                                0                            0  ...
# 1                                0                            0  ...
# 2                                0                            0  ...
# 3                                1                            0  ...
# 4                                0                            0  ...
#
#    cidade_id     nome_cidade  cod_ibge_cidade  gentilico_cidade  \
# 0       3661  Rio de Janeiro          3304557           carioca
# 1       3661  Rio de Janeiro          3304557           carioca
# 2       3602    Belford Roxo          3300456   belford-roxense
# 3       3661  Rio de Janeiro          3304557           carioca
# 4       3661  Rio de Janeiro          3304557           carioca
#
#   populacao_cidade  area_cidade densidade_demo_cidade     nome_estado  \
# 0          6320446       119746                  5.27  Rio de Janeiro
# 1          6320446       119746                  5.27  Rio de Janeiro
# 2           469332         7782                  6.03  Rio de Janeiro
# 3          6320446       119746                  5.27  Rio de Janeiro
# 4          6320446       119746                  5.27  Rio de Janeiro
#
#    uf_estado  cod_ibge_estado
# 0         RJ               33
# 1         RJ               33
# 2         RJ               33
# 3         RJ               33
# 4         RJ               33
#
# [5 rows x 23 columns]

# %% [markdown]
# Verificando se existem valores nulos

# %%
data.isnull().sum()
# Out:
# id_ocorrencia                       0
# local_ocorrencia                    0
# latitude_ocorrencia                 0
# longitude_ocorrencia                0
# data_ocorrencia                     0
# hora_ocorrencia                     0
# presen_agen_segur_ocorrencia        0
# qtd_morto_civil_ocorrencia          0
# qtd_morto_agen_segur_ocorrencia     0
# qtd_ferido_civil_ocorrencia         0
# qtd_ferido_agen_segur_ocorrencia    0
# fonte_ocorrencia                    0
# estado_id                           0
# cidade_id                           0
# nome_cidade                         0
# cod_ibge_cidade                     0
# gentilico_cidade                    0
# populacao_cidade                    0
# area_cidade                         0
# densidade_demo_cidade               0
# nome_estado                         0
# uf_estado                           0
# cod_ibge_estado                     0
# dtype: int64

# %% [markdown]
# Separação da data em campos Ano, Mês e Dia

# %%
data['data_ocorrencia'] = pd.to_datetime(data['data_ocorrencia'], errors='coerce', dayfirst=True)
data['year'], data['month'], data['day'] = data['data_ocorrencia'].dt.year, data['data_ocorrencia'].dt.month, data['data_ocorrencia'].dt.day
data.head()
# Out:
#    id_ocorrencia                                   local_ocorrencia  \
# 0           8758                  Maré; Rio de Janeiro - RJ; Brasil
# 1          10431  R. Alice - Laranjeiras; Rio de Janeiro - RJ; B...
# 2          10430            Areia Branca; Belford Roxo - RJ; Brasil
# 3             16            Santa Cruz; Rio de Janeiro - RJ; Brasil
# 4             17  Rua Barão - Praça Seca; Rio de Janeiro - RJ; B...
#
#    latitude_ocorrencia  longitude_ocorrencia data_ocorrencia hora_ocorrencia  \
# 0           -22.857496            -43.243015      2018-01-09        15:57:00
# 1           -22.935377            -43.194631      2018-01-19        20:54:00
# 2           -22.748600            -43.410628      2018-01-19        18:37:00
# 3           -22.919651            -43.684387      2016-07-05         6:02:00
# 4           -22.898642            -43.352360      2016-07-05        13:44:00
#
#    presen_agen_segur_ocorrencia  qtd_morto_civil_ocorrencia  \
# 0                             0                           0
# 1                             0                           0
# 2                             0                           0
# 3                             1                           0
# 4                             1                           0
#
#    qtd_morto_agen_segur_ocorrencia  qtd_ferido_civil_ocorrencia  ...  \
# 0                                0                            0  ...
# 1                                0                            0  ...
# 2                                0                            0  ...
# 3                                1                            0  ...
# 4                                0                            0  ...
#
#    gentilico_cidade  populacao_cidade  area_cidade  densidade_demo_cidade  \
# 0           carioca           6320446       119746                   5.27
# 1           carioca           6320446       119746                   5.27
# 2   belford-roxense            469332         7782                   6.03
# 3           carioca           6320446       119746                   5.27
# 4           carioca           6320446       119746                   5.27
#
#       nome_estado  uf_estado cod_ibge_estado  year  month  day
# 0  Rio de Janeiro         RJ              33  2018      1    9
# 1  Rio de Janeiro         RJ              33  2018      1   19
# 2  Rio de Janeiro         RJ              33  2018      1   19
# 3  Rio de Janeiro         RJ              33  2016      7    5
# 4  Rio de Janeiro         RJ              33  2016      7    5
#
# [5 rows x 26 columns]

# %%
plt.style.use('seaborn')

data['nome_cidade'].value_counts().plot.bar(color = 'mediumvioletred', figsize = (15, 10))

plt.title('Cidades com mais tiroteios',fontsize = 20)

plt.xticks(rotation = 90)
plt.show()
